# %% [markdown]
# # Setup

# %%
from proj4_code.utils import load_image, PIL_resize, generate_random_stereogram, stereo_helper_fn
from proj4_code.disparity_map import calculate_disparity_map
from proj4_code.similarity_measures import ssd_similarity_measure, sad_similarity_measure

import torch
import numpy as np

import matplotlib.pyplot as plt

from unit_tests.test_base import verify

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# We will use a helper function called stereo_helper_fn for utils.py for calculating and plotting the disparity maps using the functions defined by you

# %% [markdown]
# # Random dot stereogram

# %% [markdown]
# **Deliverables**:
# All the disparity maps
# +
# Observations and Analysis:
# 1. What is the effect of increasing the block size?
# 2. Why is the result poor on the left edge and not on the other edges?
#
# Note that implementations in disparity_map.py and similarity_measures.py should be completed before this section can work.

# %%
#generate left and right images
im_left, im_right = generate_random_stereogram(im_size=(51, 51, 3))

# %%
from unit_tests.test_utils import test_generate_random_stereogram

print('Test for random dot stereogram', verify(test_generate_random_stereogram))
# Out:
# Test for random dot stereogram "Correct"

# %% [markdown]
# Implement the similarity function and disparity map calculation. You will need it in the next steps

# %%
from unit_tests.test_similarity_measures import (
  test_ssd_similarity_measure_values, 
  test_sad_similarity_measure_values, 
  test_similarity_measure_size_compatibility
)

print('Testing value for SAD measure', verify(test_sad_similarity_measure_values))
print('Testing value for SSD measure', verify(test_ssd_similarity_measure_values))
print('Testing input size compatibility for measures', verify(test_similarity_measure_size_compatibility))
# Out:
# Testing value for SAD measure "Correct"
# Testing value for SSD measure "Correct"
# Testing input size compatibility for measures "Correct"

# %%
from unit_tests.test_disparity_map import (
  test_disparity_deltafn_failure,
  test_disparity_deltafn_success,
  test_disparity_map_size,
  test_disparity_random_stereogram,
  test_disparity_translation_shift
)

# %%
print('Testing for disparity map on a delta function', verify(test_disparity_deltafn_failure))
print('Testing for disparity map on a delta function', verify(test_disparity_deltafn_success))
print('Testing disparity map size', verify(test_disparity_map_size))
print('Testing random stereogram ouptut', verify(test_disparity_random_stereogram))
print('Testing disparity on translation shift', verify(test_disparity_translation_shift))
# Out:
# h =  0   51
# w =  0   51
# min_cost:  tensor(3.)
# tensor([[13, 30]])
# Testing for disparity map on a delta function "Wrong"
# h =  0   51
# w =  0   51
# Testing for disparity map on a delta function "Wrong"
# h =  1   14
# w =  1   14
# min_cost:  tensor(18.1704)
# min_cost:  tensor(12.3496)
# min_cost:  tensor(7.5823)
# min_cost:  tensor(2.0693)
# min_cost:  tensor(3.1928)
# min_cost:  tensor(7.6444)
# min_cost:  tensor(4.2849)
# min_cost:  tensor(5.0062)
# min_cost:  tensor(4.6211)
# min_cost:  tensor(10.9159)
# min_cost:  tensor(11.1240)
# min_cost:  tensor(9.4775)
# min_cost:  tensor(5.4875)
# min_cost:  tensor(19.7814)
# min_cost:  tensor(15.0177)
# min_cost:  tensor(10.3126)
# min_cost:  tensor(3.4057)
# min_cost:  tensor(3.5935)
# min_cost:  tensor(6.8497)
# min_cost:  tensor(9.8296)
# min_cost:  tensor(5.4964)
# min_cost:  tensor(8.7909)
# min_cost:  tensor(4.2006)
# min_cost:  tensor(5.6106)
# min_cost:  tensor(7.1276)
# min_cost:  tensor(4.1717)
# min_cost:  tensor(27.0474)
# min_cost:  tensor(7.9791)
# min_cost:  tensor(6.5301)
# min_cost:  tensor(8.7386)
# min_cost:  tensor(9.3077)
# min_cost:  tensor(8.2106)
# min_cost:  tensor(5.4728)
# min_cost:  tensor(6.4249)
# min_cost:  tensor(8.3369)
# min_cost:  tensor(5.4457)
# min_cost:  tensor(2.9281)
# min_cost:  tensor(4.3422)
# min_cost:  tensor(4.7525)
# min_cost:  tensor(20.3474)
# min_cost:  tensor(6.5468)
# min_cost:  tensor(4.7697)
# min_cost:  tensor(8.0105)
# min_cost:  tensor(8.5680)
# min_cost:  tensor(9.9832)
# min_cost:  tensor(8.7383)
# min_cost:  tensor(6.2940)
# min_cost:  tensor(10.5485)
# min_cost:  tensor(4.6388)
# min_cost:  tensor(3.0248)
# min_cost:  tensor(4.3812)
# min_cost:  tensor(4.3437)
# min_cost:  tensor(22.8859)
# min_cost:  tensor(7.2548)
# min_cost:  tensor(5.3842)
# min_cost:  tensor(8.2622)
# min_cost:  tensor(5.7642)
# min_cost:  tensor(6.4067)
# min_cost:  tensor(7.2292)
# min_cost:  tensor(2.2809)
# min_cost:  tensor(7.5155)
# min_cost:  tensor(7.0080)
# min_cost:  tensor(4.5127)
# min_cost:  tensor(6.0778)
# min_cost:  tensor(7.2461)
# min_cost:  tensor(14.3618)
# min_cost:  tensor(11.8328)
# min_cost:  tensor(10.0197)
# min_cost:  tensor(6.8793)
# min_cost:  tensor(5.2280)
# min_cost:  tensor(9.5204)
# min_cost:  tensor(5.5299)
# min_cost:  tensor(2.7697)
# min_cost:  tensor(10.3784)
# min_cost:  tensor(9.3598)
# min_cost:  tensor(8.0655)
# min_cost:  tensor(11.2151)
# min_cost:  tensor(10.0711)
# min_cost:  tensor(21.7564)
# min_cost:  tensor(18.3390)
# min_cost:  tensor(13.0813)
# min_cost:  tensor(10.2899)
# min_cost:  tensor(7.8433)
# min_cost:  tensor(10.5278)
# min_cost:  tensor(8.6850)
# min_cost:  tensor(8.3247)
# min_cost:  tensor(7.4928)
# min_cost:  tensor(11.4028)
# min_cost:  tensor(15.8233)
# min_cost:  tensor(18.6539)
# min_cost:  tensor(10.9458)
# min_cost:  tensor(25.4947)
# min_cost:  tensor(20.6189)
# min_cost:  tensor(13.8617)
# min_cost:  tensor(10.4681)
# min_cost:  tensor(9.8247)
# min_cost:  tensor(11.1816)
# min_cost:  tensor(15.8973)
# min_cost:  tensor(11.9947)
# min_cost:  tensor(10.9773)
# min_cost:  tensor(10.9854)
# min_cost:  tensor(6.9050)
# min_cost:  tensor(15.0719)
# min_cost:  tensor(7.3574)
# min_cost:  tensor(22.3587)
# min_cost:  tensor(20.4126)
# min_cost:  tensor(20.1405)
# min_cost:  tensor(16.3834)
# min_cost:  tensor(12.1737)
# min_cost:  tensor(16.1334)
# min_cost:  tensor(21.6274)
# min_cost:  tensor(10.3302)
# min_cost:  tensor(12.9619)
# min_cost:  tensor(9.1087)
# min_cost:  tensor(5.0176)
# min_cost:  tensor(4.7599)
# min_cost:  tensor(10.7574)
# min_cost:  tensor(29.9762)
# min_cost:  tensor(23.5987)
# min_cost:  tensor(23.9471)
# min_cost:  tensor(22.2157)
# min_cost:  tensor(14.0568)
# min_cost:  tensor(17.5461)
# min_cost:  tensor(18.7266)
# min_cost:  tensor(15.7815)
# min_cost:  tensor(18.4527)
# min_cost:  tensor(7.9146)
# min_cost:  tensor(9.3792)
# min_cost:  tensor(6.0526)
# min_cost:  tensor(10.5414)
# min_cost:  tensor(23.8752)
# min_cost:  tensor(17.3749)
# min_cost:  tensor(17.3805)
# min_cost:  tensor(18.5245)
# min_cost:  tensor(15.4990)
# min_cost:  tensor(11.2472)
# min_cost:  tensor(7.4830)
# min_cost:  tensor(15.0148)
# min_cost:  tensor(21.0963)
# min_cost:  tensor(14.0704)
# min_cost:  tensor(7.7104)
# min_cost:  tensor(9.0839)
# min_cost:  tensor(15.5369)
# min_cost:  tensor(23.7685)
# min_cost:  tensor(20.4097)
# min_cost:  tensor(17.0099)
# min_cost:  tensor(7.9057)
# min_cost:  tensor(8.6602)
# min_cost:  tensor(8.4215)
# min_cost:  tensor(6.2619)
# min_cost:  tensor(18.3956)
# min_cost:  tensor(15.6048)
# min_cost:  tensor(12.3278)
# min_cost:  tensor(5.9018)
# min_cost:  tensor(6.9816)
# min_cost:  tensor(11.1698)
# min_cost:  tensor(17.5011)
# min_cost:  tensor(18.3839)
# min_cost:  tensor(7.5452)
# min_cost:  tensor(7.5983)
# min_cost:  tensor(7.9128)
# min_cost:  tensor(4.8719)
# min_cost:  tensor(6.2920)
# min_cost:  tensor(17.6723)
# min_cost:  tensor(9.9328)
# min_cost:  tensor(11.2952)
# min_cost:  tensor(7.3619)
# min_cost:  tensor(6.0669)
# min_cost:  tensor(11.7350)
# h =  2   13
# w =  2   13
# min_cost:  tensor(40.4100)
# min_cost:  tensor(26.6441)
# min_cost:  tensor(22.5832)
# min_cost:  tensor(20.1891)
# min_cost:  tensor(28.7882)
# min_cost:  tensor(34.1076)
# min_cost:  tensor(25.4273)
# min_cost:  tensor(29.7690)
# min_cost:  tensor(26.7182)
# min_cost:  tensor(23.6548)
# min_cost:  tensor(24.5682)
# min_cost:  tensor(40.3552)
# min_cost:  tensor(27.4976)
# min_cost:  tensor(23.8709)
# min_cost:  tensor(25.9751)
# min_cost:  tensor(29.2132)
# min_cost:  tensor(28.0906)
# min_cost:  tensor(29.2751)
# min_cost:  tensor(28.4778)
# min_cost:  tensor(25.0287)
# min_cost:  tensor(19.2908)
# min_cost:  tensor(19.9311)
# min_cost:  tensor(39.3871)
# min_cost:  tensor(25.8627)
# min_cost:  tensor(22.0573)
# min_cost:  tensor(24.2802)
# min_cost:  tensor(23.6875)
# min_cost:  tensor(23.6077)
# min_cost:  tensor(27.9897)
# min_cost:  tensor(23.1458)
# min_cost:  tensor(19.7210)
# min_cost:  tensor(22.1310)
# min_cost:  tensor(21.8552)
# min_cost:  tensor(40.3280)
# min_cost:  tensor(31.5522)
# min_cost:  tensor(27.4614)
# min_cost:  tensor(29.6430)
# min_cost:  tensor(31.2347)
# min_cost:  tensor(27.1918)
# min_cost:  tensor(33.5283)
# min_cost:  tensor(34.1230)
# min_cost:  tensor(27.7521)
# min_cost:  tensor(19.4072)
# min_cost:  tensor(23.3167)
# min_cost:  tensor(46.6155)
# min_cost:  tensor(41.7075)
# min_cost:  tensor(30.0811)
# min_cost:  tensor(28.6099)
# min_cost:  tensor(25.0973)
# min_cost:  tensor(27.2726)
# min_cost:  tensor(34.5306)
# min_cost:  tensor(38.7919)
# min_cost:  tensor(32.8197)
# min_cost:  tensor(29.7331)
# min_cost:  tensor(33.5586)
# min_cost:  tensor(43.4449)
# min_cost:  tensor(56.3345)
# min_cost:  tensor(34.7580)
# min_cost:  tensor(37.2141)
# min_cost:  tensor(34.1894)
# min_cost:  tensor(33.7068)
# min_cost:  tensor(43.7883)
# min_cost:  tensor(46.0155)
# min_cost:  tensor(46.2226)
# min_cost:  tensor(38.6111)
# min_cost:  tensor(41.9461)
# min_cost:  tensor(60.4613)
# min_cost:  tensor(65.4205)
# min_cost:  tensor(58.0699)
# min_cost:  tensor(42.9738)
# min_cost:  tensor(48.2175)
# min_cost:  tensor(41.2603)
# min_cost:  tensor(44.4203)
# min_cost:  tensor(48.9346)
# min_cost:  tensor(45.5224)
# min_cost:  tensor(43.7471)
# min_cost:  tensor(43.2370)
# min_cost:  tensor(80.4764)
# min_cost:  tensor(77.0784)
# min_cost:  tensor(68.0969)
# min_cost:  tensor(59.4920)
# min_cost:  tensor(46.8310)
# min_cost:  tensor(43.4068)
# min_cost:  tensor(42.3589)
# min_cost:  tensor(46.0551)
# min_cost:  tensor(53.8221)
# min_cost:  tensor(46.3174)
# min_cost:  tensor(46.5823)
# min_cost:  tensor(76.2385)
# min_cost:  tensor(77.6038)
# min_cost:  tensor(65.4394)
# min_cost:  tensor(58.4571)
# min_cost:  tensor(46.4271)
# min_cost:  tensor(53.1284)
# min_cost:  tensor(49.4284)
# min_cost:  tensor(52.1335)
# min_cost:  tensor(44.5321)
# min_cost:  tensor(45.6225)
# min_cost:  tensor(51.8354)
# min_cost:  tensor(74.1068)
# min_cost:  tensor(75.1309)
# min_cost:  tensor(70.4979)
# min_cost:  tensor(53.4860)
# min_cost:  tensor(37.5063)
# min_cost:  tensor(50.0636)
# min_cost:  tensor(47.1469)
# min_cost:  tensor(51.6359)
# min_cost:  tensor(48.4865)
# min_cost:  tensor(51.8990)
# min_cost:  tensor(48.1285)
# min_cost:  tensor(70.8569)
# min_cost:  tensor(62.8801)
# min_cost:  tensor(57.9080)
# min_cost:  tensor(54.7479)
# min_cost:  tensor(32.2654)
# min_cost:  tensor(42.0270)
# min_cost:  tensor(39.0327)
# min_cost:  tensor(46.1761)
# min_cost:  tensor(41.5158)
# min_cost:  tensor(56.2845)
# min_cost:  tensor(46.2951)
# h =  3   12
# w =  3   12
# min_cost:  tensor(64.4684)
# min_cost:  tensor(60.2083)
# min_cost:  tensor(62.0609)
# min_cost:  tensor(60.3436)
# min_cost:  tensor(55.2712)
# min_cost:  tensor(75.4742)
# min_cost:  tensor(63.4272)
# min_cost:  tensor(60.9730)
# min_cost:  tensor(57.3263)
# min_cost:  tensor(71.6207)
# min_cost:  tensor(73.3260)
# min_cost:  tensor(70.3622)
# min_cost:  tensor(66.6805)
# min_cost:  tensor(65.1307)
# min_cost:  tensor(76.0765)
# min_cost:  tensor(71.7293)
# min_cost:  tensor(65.5790)
# min_cost:  tensor(60.5403)
# min_cost:  tensor(75.6690)
# min_cost:  tensor(84.4544)
# min_cost:  tensor(60.4078)
# min_cost:  tensor(62.5002)
# min_cost:  tensor(61.0061)
# min_cost:  tensor(72.4742)
# min_cost:  tensor(76.3646)
# min_cost:  tensor(69.6525)
# min_cost:  tensor(61.3764)
# min_cost:  tensor(99.0257)
# min_cost:  tensor(113.0832)
# min_cost:  tensor(72.8569)
# min_cost:  tensor(71.4042)
# min_cost:  tensor(73.2896)
# min_cost:  tensor(80.5457)
# min_cost:  tensor(87.9630)
# min_cost:  tensor(79.7981)
# min_cost:  tensor(70.7224)
# min_cost:  tensor(121.1019)
# min_cost:  tensor(125.0681)
# min_cost:  tensor(88.5394)
# min_cost:  tensor(82.8536)
# min_cost:  tensor(90.2857)
# min_cost:  tensor(91.5890)
# min_cost:  tensor(94.2003)
# min_cost:  tensor(91.1918)
# min_cost:  tensor(83.5042)
# min_cost:  tensor(127.5983)
# min_cost:  tensor(141.3923)
# min_cost:  tensor(106.0750)
# min_cost:  tensor(96.4377)
# min_cost:  tensor(95.6014)
# min_cost:  tensor(94.6915)
# min_cost:  tensor(105.2784)
# min_cost:  tensor(99.3260)
# min_cost:  tensor(90.6552)
# min_cost:  tensor(131.1153)
# min_cost:  tensor(138.0298)
# min_cost:  tensor(118.3990)
# min_cost:  tensor(102.0303)
# min_cost:  tensor(91.0900)
# min_cost:  tensor(92.7957)
# min_cost:  tensor(101.6738)
# min_cost:  tensor(109.8233)
# min_cost:  tensor(105.4226)
# min_cost:  tensor(140.4402)
# min_cost:  tensor(144.1066)
# min_cost:  tensor(125.1332)
# min_cost:  tensor(103.2477)
# min_cost:  tensor(86.1213)
# min_cost:  tensor(90.7344)
# min_cost:  tensor(101.8223)
# min_cost:  tensor(120.4416)
# min_cost:  tensor(119.8708)
# min_cost:  tensor(143.2776)
# min_cost:  tensor(139.8495)
# min_cost:  tensor(115.6006)
# min_cost:  tensor(101.6622)
# min_cost:  tensor(80.6267)
# min_cost:  tensor(83.9268)
# min_cost:  tensor(88.1261)
# min_cost:  tensor(94.5135)
# min_cost:  tensor(101.3696)
# h =  4   11
# w =  4   11
# min_cost:  tensor(143.8658)
# min_cost:  tensor(135.7198)
# min_cost:  tensor(108.2405)
# min_cost:  tensor(144.4472)
# min_cost:  tensor(143.8708)
# min_cost:  tensor(142.7532)
# min_cost:  tensor(124.4716)
# min_cost:  tensor(174.5374)
# min_cost:  tensor(159.9616)
# min_cost:  tensor(123.0037)
# min_cost:  tensor(141.7779)
# min_cost:  tensor(138.3358)
# min_cost:  tensor(152.3151)
# min_cost:  tensor(141.1546)
# min_cost:  tensor(190.5902)
# min_cost:  tensor(176.9077)
# min_cost:  tensor(146.4268)
# min_cost:  tensor(142.1666)
# min_cost:  tensor(137.4044)
# min_cost:  tensor(146.2685)
# min_cost:  tensor(142.0247)
# min_cost:  tensor(221.8884)
# min_cost:  tensor(211.3100)
# min_cost:  tensor(175.9418)
# min_cost:  tensor(166.7525)
# min_cost:  tensor(167.9512)
# min_cost:  tensor(165.5923)
# min_cost:  tensor(146.9343)
# min_cost:  tensor(217.4545)
# min_cost:  tensor(212.2588)
# min_cost:  tensor(194.1798)
# min_cost:  tensor(172.0068)
# min_cost:  tensor(172.2351)
# min_cost:  tensor(181.6007)
# min_cost:  tensor(166.8677)
# min_cost:  tensor(216.7054)
# min_cost:  tensor(227.1285)
# min_cost:  tensor(206.9044)
# min_cost:  tensor(168.7232)
# min_cost:  tensor(164.1959)
# min_cost:  tensor(180.7892)
# min_cost:  tensor(174.7059)
# min_cost:  tensor(218.4142)
# min_cost:  tensor(228.8421)
# min_cost:  tensor(216.7316)
# min_cost:  tensor(154.6420)
# min_cost:  tensor(150.7748)
# min_cost:  tensor(162.6530)
# min_cost:  tensor(157.9818)
# h =  6   9
# w =  6   9
# min_cost:  tensor(255.)
# min_cost:  tensor(255.)
# min_cost:  tensor(255.)
# min_cost:  tensor(255.)
# min_cost:  tensor(255.)
# min_cost:  tensor(255.)
# min_cost:  tensor(255.)
# min_cost:  tensor(255.)
# min_cost:  tensor(255.)
# Testing disparity map size "Correct"
# h =  2   49
# w =  2   49
# min_cost:  tensor(3.)
# min_cost:  tensor(3.)
# min_cost:  tensor(6.)
# min_cost:  tensor(9.)
# min_cost:  tensor(12.)
# min_cost:  tensor(12.)
# min_cost:  tensor(12.)
# min_cost:  tensor(9.)
# min_cost:  tensor(6.)
# min_cost:  tensor(6.)
# min_cost:  tensor(6.)
# min_cost:  tensor(6.)
# min_cost:  tensor(9.)
# min_cost:  tensor(9.)
# min_cost:  tensor(6.)
# min_cost:  tensor(3.)
# min_cost:  tensor(6.)
# min_cost:  tensor(3.)
# min_cost:  tensor(3.)
# min_cost:  tensor(3.)
# min_cost:  tensor(3.)
# min_cost:  tensor(3.)
# min_cost:  tensor(6.)
# min_cost:  tensor(6.)
# min_cost:  tensor(9.)
# min_cost:  tensor(9.)
# min_cost:  tensor(6.)
# min_cost:  tensor(3.)
# min_cost:  tensor(3.)
# min_cost:  tensor(3.)
# min_cost:  tensor(6.)
# min_cost:  tensor(9.)
# min_cost:  tensor(15.)
# min_cost:  tensor(21.)
# min_cost:  tensor(24.)
# min_cost:  tensor(24.)
# min_cost:  tensor(24.)
# min_cost:  tensor(18.)
# min_cost:  tensor(12.)
# min_cost:  tensor(9.)
# min_cost:  tensor(12.)
# min_cost:  tensor(12.)
# min_cost:  tensor(18.)
# min_cost:  tensor(18.)
# min_cost:  tensor(18.)
# min_cost:  tensor(15.)
# min_cost:  tensor(15.)
# min_cost:  tensor(12.)
# min_cost:  tensor(15.)
# min_cost:  tensor(12.)
# min_cost:  tensor(9.)
# min_cost:  tensor(9.)
# min_cost:  tensor(9.)
# min_cost:  tensor(6.)
# min_cost:  tensor(9.)
# min_cost:  tensor(12.)
# min_cost:  tensor(9.)
# min_cost:  tensor(9.)
# min_cost:  tensor(9.)
# min_cost:  tensor(6.)
# min_cost:  tensor(3.)
# min_cost:  tensor(3.)
# min_cost:  tensor(3.)
# min_cost:  tensor(9.)
# min_cost:  tensor(15.)
# min_cost:  tensor(24.)
# min_cost:  tensor(27.)
# min_cost:  tensor(21.)
# min_cost:  tensor(21.)
# min_cost:  tensor(18.)
# min_cost:  tensor(12.)
# min_cost:  tensor(12.)
# min_cost:  tensor(15.)
# min_cost:  tensor(12.)
# min_cost:  tensor(12.)
# min_cost:  tensor(12.)
# min_cost:  tensor(15.)
# min_cost:  tensor(12.)
# min_cost:  tensor(18.)
# min_cost:  tensor(15.)
# min_cost:  tensor(18.)
# min_cost:  tensor(12.)
# min_cost:  tensor(15.)
# min_cost:  tensor(12.)
# min_cost:  tensor(18.)
# min_cost:  tensor(18.)
# min_cost:  tensor(18.)
# min_cost:  tensor(18.)
# min_cost:  tensor(18.)
# min_cost:  tensor(18.)
# min_cost:  tensor(18.)
# min_cost:  tensor(18.)
# min_cost:  tensor(15.)
# min_cost:  tensor(9.)
# min_cost:  tensor(6.)
# min_cost:  tensor(3.)
# min_cost:  tensor(12.)
# min_cost:  tensor(18.)
# min_cost:  tensor(30.)
# min_cost:  tensor(27.)
# min_cost:  tensor(21.)
# min_cost:  tensor(18.)
# min_cost:  tensor(9.)
# min_cost:  tensor(6.)
# min_cost:  tensor(3.)
# min_cost:  tensor(6.)
# min_cost:  tensor(3.)
# min_cost:  tensor(6.)
# min_cost:  tensor(6.)
# min_cost:  tensor(9.)
# min_cost:  tensor(6.)
# min_cost:  tensor(9.)
# min_cost:  tensor(6.)
# min_cost:  tensor(9.)
# min_cost:  tensor(6.)
# min_cost:  tensor(9.)
# min_cost:  tensor(9.)
# min_cost:  tensor(12.)
# min_cost:  tensor(12.)
# min_cost:  tensor(15.)
# min_cost:  tensor(12.)
# min_cost:  tensor(12.)
# min_cost:  tensor(12.)
# min_cost:  tensor(9.)
# min_cost:  tensor(15.)
# min_cost:  tensor(18.)
# min_cost:  tensor(15.)
# min_cost:  tensor(9.)
# min_cost:  tensor(3.)
# min_cost:  tensor(15.)
# min_cost:  tensor(21.)
# min_cost:  tensor(33.)
# min_cost:  tensor(27.)
# min_cost:  tensor(18.)
# min_cost:  tensor(12.)
# min_cost:  tensor(3.)
# min_cost:  tensor(6.)
# min_cost:  tensor(12.)
# min_cost:  tensor(18.)
# min_cost:  tensor(9.)
# min_cost:  tensor(3.)
# min_cost:  tensor(15.)
# min_cost:  tensor(21.)
# min_cost:  tensor(33.)
# min_cost:  tensor(30.)
# min_cost:  tensor(24.)
# min_cost:  tensor(18.)
# min_cost:  tensor(6.)
# min_cost:  tensor(6.)
# min_cost:  tensor(15.)
# min_cost:  tensor(18.)
# min_cost:  tensor(9.)
# min_cost:  tensor(3.)
# min_cost:  tensor(15.)
# min_cost:  tensor(18.)
# min_cost:  tensor(30.)
# min_cost:  tensor(30.)
# min_cost:  tensor(24.)
# min_cost:  tensor(18.)
# min_cost:  tensor(6.)
# min_cost:  tensor(6.)
# min_cost:  tensor(15.)
# min_cost:  tensor(21.)
# min_cost:  tensor(9.)
# min_cost:  tensor(6.)
# min_cost:  tensor(18.)
# min_cost:  tensor(18.)
# min_cost:  tensor(27.)
# min_cost:  tensor(24.)
# min_cost:  tensor(24.)
# min_cost:  tensor(18.)
# min_cost:  tensor(6.)
# min_cost:  tensor(6.)
# min_cost:  tensor(12.)
# min_cost:  tensor(18.)
# min_cost:  tensor(6.)
# min_cost:  tensor(6.)
# min_cost:  tensor(15.)
# min_cost:  tensor(18.)
# min_cost:  tensor(24.)
# min_cost:  tensor(21.)
# min_cost:  tensor(21.)
# min_cost:  tensor(18.)
# min_cost:  tensor(6.)
# min_cost:  tensor(6.)
# min_cost:  tensor(12.)
# min_cost:  tensor(15.)
# min_cost:  tensor(3.)
# min_cost:  tensor(6.)
# min_cost:  tensor(15.)
# min_cost:  tensor(21.)
# min_cost:  tensor(30.)
# min_cost:  tensor(24.)
# min_cost:  tensor(21.)
# min_cost:  tensor(18.)
# min_cost:  tensor(6.)
# min_cost:  tensor(6.)
# min_cost:  tensor(12.)
# min_cost:  tensor(15.)
# min_cost:  tensor(6.)
# min_cost:  tensor(6.)
# min_cost:  tensor(12.)
# min_cost:  tensor(18.)
# min_cost:  tensor(27.)
# min_cost:  tensor(24.)
# min_cost:  tensor(18.)
# min_cost:  tensor(12.)
# min_cost:  tensor(3.)
# min_cost:  tensor(6.)
# min_cost:  tensor(12.)
# min_cost:  tensor(15.)
# min_cost:  tensor(3.)
# min_cost:  tensor(6.)
# min_cost:  tensor(15.)
# min_cost:  tensor(21.)
# min_cost:  tensor(27.)
# min_cost:  tensor(21.)
# min_cost:  tensor(18.)
# min_cost:  tensor(12.)
# min_cost:  tensor(3.)
# min_cost:  tensor(6.)
# min_cost:  tensor(12.)
# min_cost:  tensor(12.)
# min_cost:  tensor(3.)
# min_cost:  tensor(6.)
# min_cost:  tensor(15.)
# min_cost:  tensor(21.)
# min_cost:  tensor(24.)
# min_cost:  tensor(21.)
# min_cost:  tensor(24.)
# min_cost:  tensor(18.)
# min_cost:  tensor(6.)
# min_cost:  tensor(9.)
# min_cost:  tensor(15.)
# min_cost:  tensor(15.)
# min_cost:  tensor(6.)
# min_cost:  tensor(9.)
# min_cost:  tensor(18.)
# min_cost:  tensor(24.)
# min_cost:  tensor(27.)
# min_cost:  tensor(24.)
# min_cost:  tensor(24.)
# min_cost:  tensor(18.)
# min_cost:  tensor(6.)
# min_cost:  tensor(9.)
# min_cost:  tensor(15.)
# min_cost:  tensor(15.)
# min_cost:  tensor(6.)
# min_cost:  tensor(9.)
# min_cost:  tensor(18.)
# min_cost:  tensor(21.)
# min_cost:  tensor(21.)
# min_cost:  tensor(15.)
# min_cost:  tensor(21.)
# min_cost:  tensor(12.)
# min_cost:  tensor(3.)
# min_cost:  tensor(12.)
# min_cost:  tensor(18.)
# min_cost:  tensor(15.)
# min_cost:  tensor(6.)
# min_cost:  tensor(9.)
# min_cost:  tensor(21.)
# min_cost:  tensor(24.)
# min_cost:  tensor(24.)
# min_cost:  tensor(18.)
# min_cost:  tensor(21.)
# min_cost:  tensor(15.)
# min_cost:  tensor(3.)
# min_cost:  tensor(15.)
# min_cost:  tensor(18.)
# min_cost:  tensor(15.)
# min_cost:  tensor(9.)
# min_cost:  tensor(9.)
# min_cost:  tensor(18.)
# min_cost:  tensor(21.)
# min_cost:  tensor(21.)
# min_cost:  tensor(18.)
# min_cost:  tensor(24.)
# min_cost:  tensor(15.)
# min_cost:  tensor(3.)
# min_cost:  tensor(12.)
# min_cost:  tensor(15.)
# min_cost:  tensor(15.)
# min_cost:  tensor(12.)
# min_cost:  tensor(6.)
# min_cost:  tensor(15.)
# min_cost:  tensor(27.)
# min_cost:  tensor(30.)
# min_cost:  tensor(24.)
# min_cost:  tensor(24.)
# min_cost:  tensor(12.)
# min_cost:  tensor(3.)
# min_cost:  tensor(12.)
# min_cost:  tensor(15.)
# min_cost:  tensor(15.)
# min_cost:  tensor(9.)
# min_cost:  tensor(3.)
# min_cost:  tensor(12.)
# min_cost:  tensor(21.)
# min_cost:  tensor(30.)
# min_cost:  tensor(24.)
# min_cost:  tensor(21.)
# min_cost:  tensor(12.)
# min_cost:  tensor(3.)
# min_cost:  tensor(9.)
# min_cost:  tensor(12.)
# min_cost:  tensor(9.)
# min_cost:  tensor(9.)
# min_cost:  tensor(6.)
# min_cost:  tensor(12.)
# min_cost:  tensor(24.)
# min_cost:  tensor(30.)
# min_cost:  tensor(27.)
# min_cost:  tensor(24.)
# min_cost:  tensor(15.)
# min_cost:  tensor(3.)
# min_cost:  tensor(6.)
# min_cost:  tensor(12.)
# min_cost:  tensor(15.)
# min_cost:  tensor(9.)
# min_cost:  tensor(9.)
# min_cost:  tensor(15.)
# min_cost:  tensor(18.)
# min_cost:  tensor(27.)
# min_cost:  tensor(24.)
# min_cost:  tensor(21.)
# min_cost:  tensor(15.)
# min_cost:  tensor(3.)
# min_cost:  tensor(3.)
# min_cost:  tensor(9.)
# min_cost:  tensor(15.)
# min_cost:  tensor(9.)
# min_cost:  tensor(9.)
# min_cost:  tensor(15.)
# min_cost:  tensor(12.)
# min_cost:  tensor(18.)
# min_cost:  tensor(21.)
# min_cost:  tensor(18.)
# min_cost:  tensor(15.)
# min_cost:  tensor(3.)
# min_cost:  tensor(6.)
# min_cost:  tensor(15.)
# min_cost:  tensor(12.)
# min_cost:  tensor(6.)
# min_cost:  tensor(12.)
# min_cost:  tensor(18.)
# min_cost:  tensor(15.)
# min_cost:  tensor(18.)
# min_cost:  tensor(18.)
# min_cost:  tensor(15.)
# min_cost:  tensor(15.)
# min_cost:  tensor(6.)
# min_cost:  tensor(15.)
# min_cost:  tensor(9.)
# min_cost:  tensor(6.)
# min_cost:  tensor(12.)
# min_cost:  tensor(21.)
# min_cost:  tensor(21.)
# min_cost:  tensor(24.)
# min_cost:  tensor(18.)
# min_cost:  tensor(15.)
# min_cost:  tensor(12.)
# min_cost:  tensor(6.)
# min_cost:  tensor(12.)
# min_cost:  tensor(9.)
# min_cost:  tensor(6.)
# min_cost:  tensor(12.)
# min_cost:  tensor(24.)
# min_cost:  tensor(24.)
# min_cost:  tensor(24.)
# min_cost:  tensor(18.)
# min_cost:  tensor(15.)
# min_cost:

# %%
stereo_helper_fn(im_left, im_right, block_size = [3,5,9,13], max_search_bound=8)

# %% [markdown]
# # Error profile analysis

# %% [markdown]
# Before computing the full disparity map, we will analyse the similarity error between patches. You will have to find out different patches in the image which exhibit a close-to-convex error profile, and a highly non-convex profile.
#
# **Deliverable**:
# Find the patch in the left image and search space in the right image, and the similarity error plot for the two cases, and copy it to the report

# %%
# Load the image
base_path = '../data/adirondack/'
im_left = PIL_resize(load_image(base_path + 'im_left.png'), (0.1, 0.1))
im_right = PIL_resize(load_image(base_path + 'im_right.png'), (0.1, 0.1))

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,10))

ax1.imshow(im_left, interpolation=None)
ax1.title.set_text('Left image')
ax1.autoscale(False)
ax1.set_axis_on()

ax2.imshow(im_right, interpolation=None)
ax2.title.set_text('Right image')
ax2.autoscale(False)
ax2.set_axis_on()

plt.show()

# %% [markdown]
# ## Convex error profile

# %%
# extract a patch of interest from the left image
patch_size=15
x_idx, y_idx = (62, 65) #(None, None) # TODO: replace with integers
patch_left_img = torch.tensor(im_left[x_idx:x_idx+patch_size+1, y_idx:y_idx+patch_size+1,:])
plt.imshow(patch_left_img)
plt.show()

# %%
# get the search area in the right image
max_search_bound = 30 # might need adjustment based on your (x_idx, y_idx)
search_area_right_img = torch.tensor(
  im_right[x_idx:x_idx+patch_size+1, y_idx-max_search_bound:y_idx+patch_size+1,:]
)
plt.imshow(search_area_right_img)
plt.show()

# %%
similarity_vals = np.array(
  [sad_similarity_measure(patch_left_img, search_area_right_img[:,h_idx:h_idx+patch_size+1,:]) 
   for h_idx in range(search_area_right_img.shape[1]-patch_size-1)
  ])
plt.plot(similarity_vals)
plt.show()

# %% [markdown]
# ## Non-Convex error profile

# %%
# extract a patch of interest from the left image
patch_size=15
x_idx, y_idx = (150, 190) #(None, None) # TODO: replace with integers
patch_left_img = torch.tensor(im_left[x_idx:x_idx+patch_size+1, y_idx:y_idx+patch_size+1,:])
plt.imshow(patch_left_img)
plt.show()

# %%
# get the search area in the right image
max_search_bound = 40 # might need adjustment based on your (x_idx, y_idx)
search_area_right_img = torch.tensor(
  im_right[x_idx:x_idx+patch_size+1, y_idx-max_search_bound:y_idx+patch_size+1,:]
)
plt.imshow(search_area_right_img)
plt.show()

# %%
similarity_vals = np.array(
  [sad_similarity_measure(patch_left_img, search_area_right_img[:,h_idx:h_idx+patch_size+1,:]) 
   for h_idx in range(search_area_right_img.shape[1]-patch_size-1)
  ])
plt.plot(similarity_vals)
plt.show()

# %% [markdown]
# # Real life stereo images

# %% [markdown]
# ## Example 1

# %%
stereo_helper_fn(torch.tensor(im_left), torch.tensor(im_right), max_search_bound=25)

# %% [markdown]
# **Deliverables**
# 1. Copy the disparity map for the patch size you feel works the best
# 2. Can you think of an explanation as to why the back rest of the chair appears *blocky*?
#
# Tip: you can see all the examples and deliverables before answering. This will help you understand the core ideas being asked.

# %% [markdown]
# ## Set 2

# %%
base_path = '../data/bicycle/'
im_left = PIL_resize(load_image(base_path + 'im_left.png'), (0.1, 0.1))
im_right = PIL_resize(load_image(base_path + 'im_right.png'), (0.1, 0.1))

# %%
stereo_helper_fn(torch.tensor(im_left), torch.tensor(im_right), block_size=[11], max_search_bound=20)

# %% [markdown]
# ## Set 3

# %%
base_path = '../data/bowling/'
im_left = PIL_resize(load_image(base_path + 'im_left.png'), (0.2, 0.2))
im_right = PIL_resize(load_image(base_path + 'im_right.png'), (0.2, 0.2))

# %%
stereo_helper_fn(torch.tensor(im_left), torch.tensor(im_right), block_size=[9], max_search_bound=30)

# %% [markdown]
# ## Set 4

# %%
base_path = '../data/bowling2/'
im_left = PIL_resize(load_image(base_path + 'im_left.png'), (0.20, 0.20))
im_right = PIL_resize(load_image(base_path + 'im_right.png'), (0.20, 0.20))

# %%
stereo_helper_fn(torch.tensor(im_left), torch.tensor(im_right), block_size=[9], max_search_bound=30)

# %% [markdown]
# **Deliverables** of set 3 and set 4 combined:
#
# 1. Copy the disparity maps from set 4 in the report
# 2. Can you spot a peculiar behaviour of the diaprity maps near the head of bowling pin on the right? What do you see in the input images in that area? Can you figure out the reason behind this behaviour?
# 3. Notice that we have manipulated the images in set 4 to generate set 4 images. This leads to a difference in disparity map results in the bottom of the image and on the green bowling ball. Can you explain why the disparity drops to zero in both these regions.

# %% [markdown]
# ## Set 5

# %%
base_path = '../data/flowers/'
im_left = PIL_resize(load_image(base_path + 'im_left.png'), (0.10, 0.10))
im_right = PIL_resize(load_image(base_path + 'im_right.png'), (0.10, 0.10))

# %%
stereo_helper_fn(torch.tensor(im_left), torch.tensor(im_right), block_size=[9], max_search_bound=50)

# %% [markdown]
# **Observations**: (these observations do not go in the report. These are for your understanding).
#
# 1. Notice the different disparity of the flower at the back and its shadow
# 2. Spot the zero-disparity region in the center of the house
# 3. See how smooth the disparity values are on the couch

# %% [markdown]
# ## Set 6

# %%
base_path = '../data/stairs/'
im_left = PIL_resize(load_image(base_path + 'im_left.jpg'), (1, 1))
im_right = PIL_resize(load_image(base_path + 'im_right.jpg'), (1, 1))

# %%
stereo_helper_fn(torch.tensor(im_left), torch.tensor(im_right), block_size = [3, 5, 7], max_search_bound=15)

# %% [markdown]
# **Deliverables**
#
# 1. Why are we able to see the shift in disparity values on the wall?
# 2. What is the effect of block_size and the ability to see stairs-like structure in the disparity map?

# %% [markdown]
# # Smoothing

# %% [markdown]
# One issue with the results from is that they aren't very smooth. Pixels next to each other on the same surface can have vastly different disparities, making the results look very noisy and patchy in some areas. Intuitively, pixels next to each other should have a smooth transition in disparity(unless at an object boundary or occlusion).
# In this section, we try to improve our results. One way of doing this is through the use of a smoothing constraint. The smoothing method we use is called Semi-Global Matching(SGM) or Semi-Global Block Matching. Before, we picked the disparity for a pixel based on the minimum matching cost of the block using some metric(SSD or SAD). The basic idea of SGM is to penalize pixels with a disparity that's very different than their neighbors by adding a penalty term on top of the matching cost term. SGM tries to minimize the global(over the entire image) energy function
# \begin{equation*}
# E(D) \leq \sum_{p} (C(p, D_p) + \sum_{q} PT(|D_p - D_q|))
# \end{equation*}
# C(p,D_p) is the matching cost for a pixel with disparity D_p, q is a neighboring pixel, and PT is some penalty function penalizing the difference in disparities.
# You can read more about how this method works and is optimized here:
# https://elib.dlr.de/73119/1/180Hirschmueller.pdf
# and
# https://pdfs.semanticscholar.org/bcd8/4d8bd864ff903e3fe5b91bed3f2eedacc324.pdf

# %% [markdown]
# Before we implement the smoothing algorithm, we need to implement a function which computes the **cost volume**. We have already written code to compute disparity map. We will extend that code to compute the cost volume. Instead of taking the argmin of the similarity error profile, we will store the tensor of error profile at each pixel location along the third dimension.
#
# If we have an input image of dimension (H,W,C) and max search bound of D, the cost_volume will be a tensor of dimension (H,W,D). The cost volumne at (i,j) pixel is the error profile obtained for the patch in the left image centered at (i,j).
#
# Implement this part as function ```calculate_cost_volume``` in ```disparity_map.py```. Feel free to reuse any code you have written till now.

# %%
from unit_tests.test_disparity_map import (
  test_calculate_cost_volume
)

print('Testing for calculate_cost_volume', verify(test_calculate_cost_volume))

# %%
# Load the image
from semiglobalmatching.sgm import sgm
from scipy import ndimage
from proj4_code.similarity_measures import sad_similarity_measure, ssd_similarity_measure

#you can change the path to try other pairs, but you may need to fix the scaling per pair
base_path = '../data/adirondack/'
im_left = PIL_resize(load_image(base_path + 'im_left.png'), (0.10, 0.10))
im_right = PIL_resize(load_image(base_path + 'im_right.png'), (0.10, 0.10))

#calculates the disparity map with SGM, the last argument is max disparity to consider
disparity_map = sgm(im_left,im_right, "result", 30, sad_similarity_measure, 9)
result = ndimage.median_filter(disparity_map, size=5)
plt.figure()
plt.imshow(result, cmap='jet', interpolation='nearest')
plt.title('Disparity map')
plt.colorbar()
plt.show()

# %% [markdown]
# **Deliverables**
#
# 1. Compare these results qualitatively to the output of the chair image without smoothing.
# 2. What regions of the image does smoothing seem to perform better on and why do you think that is?
# 3. What regions of the image does smoothing seem to perform worse on and why do you think that is?
# 4. Would smoothing still work for images with both a horizontal and vertical shift?
#
#
# (Extra Credit)Try the above smoothing with your own image pair! Take 2 images with only(or mostly) a horizontal shift, and see the result by editing the image paths and running the code. If you get good results, explain why your image pair is "easy". If you get bad results, explain why your pair is "hard". These results go in the extra credit slides.
